# %%
import pandas as pd
in_file = "./u12_2013_2011.csv"
u18_df = pd.read_csv(in_file,encoding="UTF-8")

# %%
#列の順番を整理する time,playerの列を削除
u18_df=u18_df.loc[:,['id','leagu_name','year','month','day','round','team_home','team_away','url','results_away','results_home','goal_away','goal_home']]
u18_df.head(3)
# u18_df.shape
# Out:
#    id       leagu_name  year month  day         round team_home team_away  \
# 0   2  第37回全日本少年サッカー大会  2013   07月  29日   第1節No.2 第1節     十市ＳＳＣ    レジスタＦＣ
# 1   1  第37回全日本少年サッカー大会  2013   07月  29日   第1節No.1 第1節  ピナクル倉敷ＦＣ    八幡台ＪＳＣ
# 2  25  第37回全日本少年サッカー大会  2013   07月  29日  第2節No.25 第2節  ピナクル倉敷ＦＣ     十市ＳＳＣ
#
#                                                  url  results_away  \
# 0  http://www.jfa.or.jp/match/matches/2013/0803ze...             9
# 1  http://www.jfa.or.jp/match/matches/2013/0803ze...             2
# 2  http://www.jfa.or.jp/match/matches/2013/0803ze...             0
#
#    results_home                                          goal_away  \
# 0             0  8分 木下 翼,19分 木下 翼,21分 白石 稜拓,25分 木下 翼,26分 木下 翼,2...
# 1             0                                 13分 中屋 愛斗,28分 南 翔太
# 2             4                                               None
#
#                                 goal_home
# 0                                    None
# 1                                    None
# 2  2分 山田 恭也,27分 山田 恭也,29分 村上 尚哉,40分 山田 恭也

# %%
# スコアがNone(=未実施)の試合の行を削除
u18_df=u18_df[u18_df['results_away'] != "None"]
u18_df.shape
# Out:
# c:\users\leo\env_django\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# (400, 13)

# %%
# 年が変わるときの行(カラム名が入っている)を削除(一応...)
u18_df=u18_df[u18_df['results_away'] != "results_away"]
u18_df.shape
# Out:
# (400, 13)

# %%
#今回は、2013以外を抽出
u18_df=u18_df[u18_df['year'] != int("2013")]
u18_df
# Out:
#       id       leagu_name  year month  day             round    team_home  \
# 129   26  第36回全日本少年サッカー大会  2012   07月  31日      第2節No.26 第2節    アルビレックス新潟
# 135    4  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.4 第1節    フォルツァ松本ＦＣ
# 136   55  第36回全日本少年サッカー大会  2012   08月  01日      第3節No.55 第3節       太陽延岡ＳＣ
# 137   28  第36回全日本少年サッカー大会  2012   07月  31日      第2節No.28 第2節         青森ＦＣ
# 138    3  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.3 第1節       太陽延岡ＳＣ
# 139   27  第36回全日本少年サッカー大会  2012   07月  31日      第2節No.27 第2節       太陽延岡ＳＣ
# 140   56  第36回全日本少年サッカー大会  2012   08月  01日      第3節No.56 第3節         青森ＦＣ
# 141   53  第36回全日本少年サッカー大会  2012   08月  01日      第3節No.53 第3節      ＦＣ．ＳＥＴＡ
# 142    2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節         川上ＦＣ
# 143    1  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.1 第1節      ＦＣ．ＳＥＴＡ
# 144   25  第36回全日本少年サッカー大会  2012   07月  31日      第2節No.25 第2節      ＦＣ．ＳＥＴＡ
# 145   54  第36回全日本少年サッカー大会  2012   08月  01日      第3節No.54 第3節    アルビレックス新潟
# 146   31  第36回全日本少年サッカー大会  2012   07月  31日      第2節No.31 第2節       京都紫光ＳＣ
# 147    8  第36回全日本少年サッカー大会  2012   07月  31日       第1節No
ＦＣ  http://www.jfa.or.jp/match/matches/2011/0806ze...
#
#      results_away  results_home  \
# 129             0             3
# 135             2             5
# 136             4             5
# 137             2             1
# 138             0             1
# 139             0             3
# 140             1             2
# 141             5             0
# 142             5             1
# 143             3             0
# 144             2             1
# 145             1             3
# 146             0             1
# 147             2             3
# 148             3             5
# 149             0             1
# 150             0             4
# 151             1             1
# 152             2             0
# 153             7             0
# 154             2             1
# 155             2             1
# 156             1             2
# 157             0             3
# 158             1             4
# 159             5             0
# 160             1             0
# 161             4             0
# 162             5             2
# 163             2             1
# ..            ...           ...
# 370             2             2
# 371             0             2
# 372             0             1
# 373             1             4
# 374             0             2
# 375             2             0
# 376             2             1
# 377             2             1
# 378             2             0
# 379             0             2
# 380             2             2
# 381             2             1
# 382             1             6
# 383             1             0
# 384             0             1
# 385             0             0
# 386             1             3
# 387             0             0
# 388             1             1
# 389             3             2
# 390             4             0
# 391             4             1
# 392             1             6
# 393             2             2
# 394             1             2
# 395             1             2
# 396             4             4
# 397             1             3
# 398             3             1
# 399             5             0
#
#                                              goal_away  \
# 129                                                NaN
# 135                                3分 富田 仁志,31分 富田 仁志,
# 136            6分 富田 仁志,31分 横山 智也,32分 富田 仁志,39分 富田 仁志,
# 137                                4分 横山 智也,28分 髙井 碩斗,
# 138                                                NaN
# 139                                                NaN
# 140                                       20+1分 二木 七翼,
# 141  8分 太田和 隆斗,10分 森 海渡,13分 太田和 隆斗,22分 貞廣 大輔,40+1分 ...
# 142    12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 143                    10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 144                             22分 橋口 緒斗,40+1分 森薗 龍馬,
# 145                                         16分 吉満 採弥,
# 146                                                NaN
# 147                             6分 閑田 隼斗,40+2分 大堀 亮之介,
# 148                    15分 田原 裕次郎,17分 松木 悠人,27分 真鍋 昻羽,
# 149                                                NaN
# 150                                                NaN
# 151                                         26分 西田 郁也,
# 152                                17分 閑田 隼斗,29分 桂 陸人,
# 153  14分 加藤木 寛太,22分 原 豪汰,28分 原 豪汰,30分 原 豪汰,34分 宮嶋 俊...
# 154                             29分 小沼 樹輝,40+1分 金原 朝陽,
# 155                                9分 大和田 涼太,34分 岡本 竜,
# 156                                          5分 田浦 陽平,
# 157                                                NaN
# 158                                          1分 沼田 知大,
# 159  2分 細川 朝陽,31分 山﨑 大嗣,35分 児島 信之介,40分 堀内 塁,40+3分 中...
# 160                                         14分 高橋 佳汰,
# 161            18分 生井澤 呼範,24分 網中 神,27分 額賀 拓海,36分 網中 神,
# 162  6分 上田 一也,22分 鈴木 悠斗,27分 上田 一也,36分 鈴木 悠斗,40+3分 高...
# 163                              10分 有馬 幸太郎,21分 小沼 樹輝,
# ..                                                 ...
# 370                              8分 吉儀　祐希,20+1分 石倉　一彰,
# 371                                                NaN
# 372                                                NaN
# 373                                       20+2分 小林　大修,
# 374                                                NaN
# 375                                 6分 米田　竜也,17分 畔道　徹,
# 376                               15分 佐藤　大樹,39分 青木　俊佑,
# 377                                 4分 石田　雄大,5分 濱口　聡太,
# 378                                 2分 濱口　聡太,9分 石田　雄大,
# 379                                                NaN
# 380                               30分 鮎瀬　英郎,34分 能村　悠平,
# 382  2分 佐藤　海成,14分 鈴木　悠斗,19分 鈴木　悠斗,25分 渡辺　空斗,37分 小林　...
# 383                                                NaN
# 384                                         16分 永田　椋也,
# 385                                               None
# 386                    8分 阿部　光将,13分 梶谷　政仁,20+1分 菅波　大輝,
# 387                                               None
# 388                                       40+1分 打田　翔瑚,
# 389                             28分 高橋　秀斗,40+1分 市原　寅希,
# 390                                                NaN
# 391                                        22分 副島　龍太郎,
# 392  1分 吉田　樹,23分 安孫子　裕輔,27分 吉田　篤志,30分 吉田　樹,33分 安孫子　...
# 393                               2分 安孫子　裕輔,10分 吉田　篤志,
# 394                                 4分 吉田　樹,38分 鈴木　優太,
# 395                               1分 菅波　大輝,20+1分 岡本　竜,
# 396            1分 梶谷　政仁,16分 阿部　光将,20+2分 岡本　竜,34分 岡本　竜,
# 397                      4分 木田　寿輝斗,9分 濱本　周,31分 木田　寿輝斗,
# 398                                      40+2分 木田　寿輝斗,
# 399                                                NaN
#
# [266 rows x 13 columns]

# %%
# # yearに"2002"が入ってしまっているものの対処(未実装)
# u18_df=u18_df[u18_df['year'].str.match('.*,2002')!= "True"]
# u18_df.shape

# %%
#idの混同を避けるため、idとyearを合わせる
u18_df["merg_id"] = u18_df["year"].astype(str)+u18_df["id"].astype(str)
u18_df["merg_id"] = u18_df["merg_id"].astype(int)
u18_df.dtypes
# Out:
# id               int64
# leagu_name      object
# year             int64
# month           object
# day             object
# round           object
# team_home       object
# team_away       object
# url             object
# results_away     int64
# results_home     int64
# goal_away       object
# goal_home       object
# merg_id          int32
# dtype: object

# %%
# ここからaway

# %%
#awayチームの得点者とその試合のidのみを抜き出す
df_spr_away = pd.DataFrame(u18_df['goal_away'].str.split(',', expand=True))
df_spr_away["merg_id"] =u18_df["merg_id"]
df_spr_away.head(10)
# Out:
#                0           1           2          3            4     5     6  \
# 129          NaN         NaN         NaN        NaN          NaN   NaN   NaN
# 135     3分 富田 仁志   31分 富田 仁志                   None         None  None  None
# 136     6分 富田 仁志   31分 横山 智也   32分 富田 仁志  39分 富田 仁志               None  None
# 137     4分 横山 智也   28分 髙井 碩斗                   None         None  None  None
# 138          NaN         NaN         NaN        NaN          NaN   NaN   NaN
# 139          NaN         NaN         NaN        NaN          NaN   NaN   NaN
# 140  20+1分 二木 七翼                    None       None         None  None  None
# 141    8分 太田和 隆斗    10分 森 海渡  13分 太田和 隆斗  22分 貞廣 大輔  40+1分 窪田 亮輔        None
# 142     12分 森 海渡  20分 太田和 隆斗    23分 森 海渡   25分 森 海渡     29分 森 海渡        None
# 143   10分 瀬賀 凜太郎   16分 松田 拓馬   18分 佐藤 圭祐                    None  None  None
#
#         7     8     9    10    11    12  merg_id
# 129   NaN   NaN   NaN   NaN   NaN   NaN   201226
# 135  None  None  None  None  None  None    20124
# 136  None  None  None  None  None  None   201255
# 137  None  None  None  None  None  None   201228
# 138   NaN   NaN   NaN   NaN   NaN   NaN    20123
# 139   NaN   NaN   NaN   NaN   NaN   NaN   201227
# 140  None  None  None  None  None  None   201256
# 141  None  None  None  None  None  None   201253
# 142  None  None  None  None  None  None    20122
# 143  None  None  None  None  None  None    20121

# %%
# 先ほどの表から、1ゴール目のデータだけの表を作り、ゴールのない試合は削除
df_spr_away0 = pd.DataFrame({
    "goal":df_spr_away[0],
    "merg_id":df_spr_away["merg_id"]
})
df_spr_away0["count_away"]=int("1")
# df_spr_away0.isnull().sum()
df_spr_away0.tail()
# Out:
#            goal  merg_id  count_away
# 395   35分 渡辺　空斗  2011127           1
# 396     3分 吉田　樹  2011130           1
# 397  40+2分 畔道　徹  2011121           1
# 398   23分 曽根　玲英  2011129           1
# 399   15分 河合　瑞季  2011122           1

# %%
#2ゴール目以降のデータも追加
for repeat in range(1, ( (len(df_spr_away.columns)) -2) ):
    df_spr_away_n = pd.DataFrame({
    "goal":df_spr_away[repeat],
    "merg_id":df_spr_away["merg_id"],
    })
    df_spr_away_n["count_away"]=int(repeat+1)
    df_spr_away0 = pd.concat([df_spr_away0,df_spr_away_n],sort=True,copy=False,ignore_index=True)


df_spr_away0.tail()
# Out:
#       count_away  goal  merg_id
# 3187          12  None  2011127
# 3188          12  None  2011130
# 3189          12  None  2011121
# 3190          12  None  2011129
# 3191          12  None  2011122

# %%
# 空白やNoneを消す
df_spr_away0 = df_spr_away0[df_spr_away0['goal'] != "None"]
df_spr_away0 = df_spr_away0[df_spr_away0['goal'] != ""]
df_spr_away0.dropna(inplace=True) 
# df_spr_away0.isnull().sum()

df_spr_away0.tail()
# Out:
#       count_away         goal  merg_id
# 2277           9    25分 奥抜　侃志   201129
# 2454          10      36分 原 尊   201265
# 2543          10   33分 鵜生川　治臣   201129
# 2809          11    37分 奥抜　侃志   201129
# 3075          12  40+2分 奥抜　侃志   201129

# %%
#選手名と時間を分ける
df_spr_away0 = pd.concat([df_spr_away0,df_spr_away0["goal"].str.split("分",expand=True)],axis=1).drop("goal", axis=1)
df_spr_away0.rename(columns={0: 'time', 1: 'player'}, inplace=True)

# additional timeで別カラム
df_spr_away0 = pd.concat([df_spr_away0,df_spr_away0["time"].str.split("+",expand=True)],axis=1).drop("time", axis=1).fillna(-1)
df_spr_away0.rename(columns={0: 'n_time', 1: 'a_time'}, inplace=True)
df_spr_away0["n_time"] =df_spr_away0["n_time"].astype(int)
df_spr_away0["a_time"] =df_spr_away0["a_time"].astype(int)


df_spr_away0.head()
# Out:
#    count_away  merg_id   player  n_time  a_time
# 1           1    20124    富田 仁志       3      -1
# 2           1   201255    富田 仁志       6      -1
# 3           1   201228    横山 智也       4      -1
# 6           1   201256    二木 七翼      20       1
# 7           1   201253   太田和 隆斗       8      -1

# %%
# 名前に「分」が入ってる人
def inc_hunn(df):
    try:
        df.loc[ (df[3] != -1 ), "player"] = df["player"].astype(str) + str("分") + df[2].astype(str)
        del df[3]
        return df
    except:
        try:
            df.loc[ (df[2] != -1 ), "player"] = df["player"].astype(str) + str("分") + df[2].astype(str)
            del df[2]
            return df
        except:
            pass
inc_hunn(df_spr_away0)

# %%
#ここからhome

# %%
#homeチームの得点者とその試合のidのみを抜き出す
df_spr_home = pd.DataFrame(u18_df['goal_home'].str.split(',', expand=True))
df_spr_home["merg_id"] =u18_df["merg_id"]
df_spr_home.tail()
# Out:
#                 0           1           2         3     4     5     6     7  \
# 395      1分 菅波　大輝  20+1分 岡本　竜                  None  None  None  None  None
# 396      1分 梶谷　政仁   16分 阿部　光将  20+2分 岡本　竜  34分 岡本　竜        None  None  None
# 397     4分 木田　寿輝斗     9分 濱本　周  31分 木田　寿輝斗            None  None  None  None
# 398  40+2分 木田　寿輝斗                    None      None  None  None  None  None
# 399           NaN         NaN         NaN       NaN   NaN   NaN   NaN   NaN
#
#         8     9    10    11    12  merg_id
# 395  None  None  None  None  None  2011127
# 396  None  None  None  None  None  2011130
# 397  None  None  None  None  None  2011121
# 398  None  None  None  None  None  2011129
# 399   NaN   NaN   NaN   NaN   NaN  2011122

# %%
# 先ほどの表から、1ゴール目のデータだけの表を作り、ゴールのない試合は削除
df_spr_home0 = pd.DataFrame({
    "goal":df_spr_home[0],
    "merg_id":df_spr_home["merg_id"]
})

df_spr_home0["count_home"]=int(1)

#2ゴール目以降のデータも追加
for repeat in range(1, ( (len(df_spr_home.columns)) -2) ):
    df_spr_home_n = pd.DataFrame({
    "goal":df_spr_home[repeat],
    "merg_id":df_spr_home["merg_id"],
    })
    df_spr_home_n["count_home"]=int(repeat+1)
    df_spr_home0 = pd.concat([df_spr_home0,df_spr_home_n],sort=True,copy=False,ignore_index=True)

df_spr_home0.tail()
# Out:
#       count_home  goal  merg_id
# 3187          12  None  2011127
# 3188          12  None  2011130
# 3189          12  None  2011121
# 3190          12  None  2011129
# 3191          12   NaN  2011122

# %%
# 空白やNoneを消す
df_spr_home0=df_spr_home0[df_spr_home0['goal'] != "None"] 
df_spr_home0=df_spr_home0[df_spr_home0['goal'] != ""] 
df_spr_home0.dropna(inplace=True)
df_spr_home0.tail()
# Out:
#       count_home         goal  merg_id
# 2336           9    21分 石田　壮汰   201187
# 2432          10  40+2分 深澤 大成   201237
# 2602          10    26分 中村　駿太   201187
# 2868          11    29分 石田　壮汰   201187
# 3134          12    34分 中村　駿太   201187

# %%
#選手名と時間を分ける
df_spr_home0 = pd.concat([df_spr_home0,df_spr_home0["goal"].str.split("分",expand=True)],axis=1).drop("goal", axis=1)
df_spr_home0.rename(columns={0: 'time', 1: 'player'}, inplace=True)

# additional timeで別カラム
df_spr_home0 = pd.concat([df_spr_home0,df_spr_home0["time"].str.split("+",expand=True)],axis=1).drop("time", axis=1).fillna(-1)
df_spr_home0.rename(columns={0: 'n_time', 1: 'a_time'}, inplace=True)
df_spr_home0["n_time"] =df_spr_home0["n_time"].astype(int)
df_spr_home0["a_time"] =df_spr_home0["a_time"].astype(int)

df_spr_home0.head()
# Out:
#    count_home  merg_id   player  n_time  a_time
# 0           1   201226    松田 拓馬       2      -1
# 1           1    20124    児玉 拓朗       6      -1
# 2           1   201255     河原 淳       7      -1
# 3           1   201228   向中野 翔摩       8      -1
# 4           1    20123     河原 淳      10      -1

# %%
# 名前に「分」が入ってる人(いない場合はエラー、無視して次に進む)
inc_hunn(df_spr_home0)

# %%
#ここからまとめて

# %%
#homeとawayを合体 #並び変える（ソート）
df_merge = pd.concat([df_spr_away0,df_spr_home0],sort=True,copy=False,ignore_index=True)

#試合情報を結合
u18_df["id"]=u18_df["id"].astype(int)
df_merged = pd.merge(df_merge,u18_df, on="merg_id").sort_values(["year","id","n_time","a_time"],ascending=[False,True,True,True]).reset_index(drop=True)

df_merged["differ"] =df_merged["merg_id"].diff().fillna(1)
df_merged.head(20)
# Out:
#     a_time  count_away  count_home  merg_id  n_time   player  id  \
# 0       -1         1.0         NaN    20121      10   瀬賀 凜太郎   1
# 1       -1         2.0         NaN    20121      16    松田 拓馬   1
# 2       -1         3.0         NaN    20121      18    佐藤 圭祐   1
# 3       -1         1.0         NaN    20122      12     森 海渡   2
# 4       -1         2.0         NaN    20122      20   太田和 隆斗   2
# 5       -1         3.0         NaN    20122      23     森 海渡   2
# 6       -1         4.0         NaN    20122      25     森 海渡   2
# 7       -1         5.0         NaN    20122      29     森 海渡   2
# 8       -1         NaN         1.0    20122      37    橋口 緒斗   2
# 9       -1         NaN         1.0    20123      10     河原 淳   3
# 10      -1         1.0         NaN    20124       3    富田 仁志   4
# 11      -1         NaN         1.0    20124       6    児玉 拓朗   4
# 12      -1         NaN         2.0    20124       8    児玉 拓朗   4
# 13      -1         2.0         NaN    20124      31    富田 仁志   4
# 14      -1         NaN         3.0    20124      36    児玉 拓朗   4
# 15      -1         NaN         4.0    20124      37    二木 七翼   4
# 16      -1         NaN         5.0    20124      38    児玉 拓朗   4
# 17      -1         NaN         1.0    20125       8    手塚 周太   5
# 18      -1         NaN         2.0    20125       9    小林 龍太   5
# 19      -1         NaN         3.0    20125      14    手塚 周太   5
#
#          leagu_name  year month  day        round  team_home  team_away  \
# 0   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 1   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 2   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 3   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 4   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 5   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 6   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 7   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 8   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 9   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.3 第1節     太陽延岡ＳＣ       青森ＦＣ
# 10  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 11  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 12  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 13  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 14  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 15  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 16  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 17  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
# 18  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
# 19  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
#
#                                                   url  results_away  \
# 0   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 1   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 2   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 3   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 4   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 5   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 6   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 7   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 8   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 9   http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 10  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 11  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 12  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 13  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 14  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 15  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 16  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 17  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 18  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 19  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
#
#     results_home                                        goal_away  \
# 0              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 1              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 2              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 3              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 4              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 5              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 6              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 7              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 8              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 9              1                                              NaN
# 10             5                              3分 富田 仁志,31分 富田 仁志,
# 11             5                              3分 富田 仁志,31分 富田 仁志,
# 12             5                              3分 富田 仁志,31分 富田 仁志,
# 13             5                              3分 富田 仁志,31分 富田 仁志,
# 14             5                              3分 富田 仁志,31分 富田 仁志,
# 15             5                              3分 富田 仁志,31分 富田 仁志,
# 16             5                              3分 富田 仁志,31分 富田 仁志,
# 17             3                                              NaN
# 18             3                                              NaN
# 19             3                                              NaN
#
#                                            goal_home  differ
# 0                                                NaN     1.0
# 1                                                NaN     0.0
# 2                                                NaN     0.0
# 3                                         37分 橋口 緒斗,     1.0
# 4                                         37分 橋口 緒斗,     0.0
# 5                                         37分 橋口 緒斗,     0.0
# 6                                         37分 橋口 緒斗,     0.0
# 7                                         37分 橋口 緒斗,     0.0
# 8                                         37分 橋口 緒斗,     0.0
# 9                                          10分 河原 淳,     1.0
# 10  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     1.0
# 11  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 12  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 13  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 14  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 15  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 16  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 17                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     1.0
# 18                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     0.0
# 19                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     0.0

# %%
# #なぜかわからないけど、同じゴールが入っている行を削除
# def kakuni(df):
#     df=df[df['count_home'] != df['count_home'].shift(1)]
    
# df_merged = kakuni(df_merged)
# df_merged.head(20)

# %%
#idが変わる試合 かつ counthomeがnullのもの(=相手が先制しているので、counthomeは0になるべき)
df_merged.loc[(df_merged["differ"] != 0.0) &  (df_merged["count_home"].isnull() ), "count_home"] = 0
#awayも同様
df_merged.loc[(df_merged["differ"] != 0.0) &  (df_merged["count_away"].isnull() ), "count_away"] = 0

df_merged.head()
# Out:
#    a_time  count_away  count_home  merg_id  n_time   player  id  \
# 0      -1         1.0         0.0    20121      10   瀬賀 凜太郎   1
# 1      -1         2.0         NaN    20121      16    松田 拓馬   1
# 2      -1         3.0         NaN    20121      18    佐藤 圭祐   1
# 3      -1         1.0         0.0    20122      12     森 海渡   2
# 4      -1         2.0         NaN    20122      20   太田和 隆斗   2
#
#         leagu_name  year month  day        round team_home  team_away  \
# 0  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 1  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 2  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 3  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節      川上ＦＣ      柏レイソル
# 4  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節      川上ＦＣ      柏レイソル
#
#                                                  url  results_away  \
# 0  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 1  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 2  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 3  http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 4  http://www.jfa.or.jp/match/matches/2012/0804ze...             5
#
#    results_home                                        goal_away   goal_home  \
# 0             0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,         NaN
# 1             0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,         NaN
# 2             0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,         NaN
# 3             1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,  37分 橋口 緒斗,
# 4             1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,  37分 橋口 緒斗,
#
#    differ
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
#残りのNaNは、相手ゴール分なので、一つ上の行のデータで埋める
df_merged["count_away"]=df_merged["count_away"].fillna(method='ffill')
df_merged["count_home"]=df_merged["count_home"].fillna(method='ffill')
df_merged.head(20)
# Out:
#     a_time  count_away  count_home  merg_id  n_time   player  id  \
# 0       -1         1.0         0.0    20121      10   瀬賀 凜太郎   1
# 1       -1         2.0         0.0    20121      16    松田 拓馬   1
# 2       -1         3.0         0.0    20121      18    佐藤 圭祐   1
# 3       -1         1.0         0.0    20122      12     森 海渡   2
# 4       -1         2.0         0.0    20122      20   太田和 隆斗   2
# 5       -1         3.0         0.0    20122      23     森 海渡   2
# 6       -1         4.0         0.0    20122      25     森 海渡   2
# 7       -1         5.0         0.0    20122      29     森 海渡   2
# 8       -1         5.0         1.0    20122      37    橋口 緒斗   2
# 9       -1         0.0         1.0    20123      10     河原 淳   3
# 10      -1         1.0         0.0    20124       3    富田 仁志   4
# 11      -1         1.0         1.0    20124       6    児玉 拓朗   4
# 12      -1         1.0         2.0    20124       8    児玉 拓朗   4
# 13      -1         2.0         2.0    20124      31    富田 仁志   4
# 14      -1         2.0         3.0    20124      36    児玉 拓朗   4
# 15      -1         2.0         4.0    20124      37    二木 七翼   4
# 16      -1         2.0         5.0    20124      38    児玉 拓朗   4
# 17      -1         0.0         1.0    20125       8    手塚 周太   5
# 18      -1         0.0         2.0    20125       9    小林 龍太   5
# 19      -1         0.0         3.0    20125      14    手塚 周太   5
#
#          leagu_name  year month  day        round  team_home  team_away  \
# 0   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 1   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 2   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節    ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 3   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 4   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 5   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 6   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 7   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 8   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節       川上ＦＣ      柏レイソル
# 9   第36回全日本少年サッカー大会  2012   07月  31日  第1節No.3 第1節     太陽延岡ＳＣ       青森ＦＣ
# 10  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 11  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 12  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 13  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 14  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 15  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 16  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.4 第1節  フォルツァ松本ＦＣ       高富ＳＳ
# 17  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
# 18  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
# 19  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.5 第1節   Ｕスポーツクラブ       大松ＦＣ
#
#                                                   url  results_away  \
# 0   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 1   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 2   http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 3   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 4   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 5   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 6   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 7   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 8   http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 9   http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 10  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 11  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 12  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 13  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 14  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 15  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 16  http://www.jfa.or.jp/match/matches/2012/0804ze...             2
# 17  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 18  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
# 19  http://www.jfa.or.jp/match/matches/2012/0804ze...             0
#
#     results_home                                        goal_away  \
# 0              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 1              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 2              0                  10分 瀬賀 凜太郎,16分 松田 拓馬,18分 佐藤 圭祐,
# 3              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 4              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 5              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 6              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 7              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 8              1  12分 森 海渡,20分 太田和 隆斗,23分 森 海渡,25分 森 海渡,29分 森 海渡,
# 9              1                                              NaN
# 10             5                              3分 富田 仁志,31分 富田 仁志,
# 11             5                              3分 富田 仁志,31分 富田 仁志,
# 12             5                              3分 富田 仁志,31分 富田 仁志,
# 13             5                              3分 富田 仁志,31分 富田 仁志,
# 14             5                              3分 富田 仁志,31分 富田 仁志,
# 15             5                              3分 富田 仁志,31分 富田 仁志,
# 16             5                              3分 富田 仁志,31分 富田 仁志,
# 17             3                                              NaN
# 18             3                                              NaN
# 19             3                                              NaN
#
#                                            goal_home  differ
# 0                                                NaN     1.0
# 1                                                NaN     0.0
# 2                                                NaN     0.0
# 3                                         37分 橋口 緒斗,     1.0
# 4                                         37分 橋口 緒斗,     0.0
# 5                                         37分 橋口 緒斗,     0.0
# 6                                         37分 橋口 緒斗,     0.0
# 7                                         37分 橋口 緒斗,     0.0
# 8                                         37分 橋口 緒斗,     0.0
# 9                                          10分 河原 淳,     1.0
# 10  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     1.0
# 11  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 12  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 13  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 14  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 15  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 16  6分 児玉 拓朗,8分 児玉 拓朗,36分 児玉 拓朗,37分 二木 七翼,38分 児玉 拓朗,     0.0
# 17                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     1.0
# 18                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     0.0
# 19                      8分 手塚 周太,9分 小林 龍太,14分 手塚 周太,     0.0

# %%
df_merged["goal_away"]=df_merged["count_away"].astype(int)
df_merged["goal_home"]=df_merged["count_home"].astype(int)
df_merged.head()
# Out:
#    a_time  count_away  count_home  merg_id  n_time   player  id  \
# 0      -1         1.0         0.0    20121      10   瀬賀 凜太郎   1
# 1      -1         2.0         0.0    20121      16    松田 拓馬   1
# 2      -1         3.0         0.0    20121      18    佐藤 圭祐   1
# 3      -1         1.0         0.0    20122      12     森 海渡   2
# 4      -1         2.0         0.0    20122      20   太田和 隆斗   2
#
#         leagu_name  year month  day        round team_home  team_away  \
# 0  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 1  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 2  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.1 第1節   ＦＣ．ＳＥＴＡ  アルビレックス新潟
# 3  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節      川上ＦＣ      柏レイソル
# 4  第36回全日本少年サッカー大会  2012   07月  31日  第1節No.2 第1節      川上ＦＣ      柏レイソル
#
#                                                  url  results_away  \
# 0  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 1  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 2  http://www.jfa.or.jp/match/matches/2012/0804ze...             3
# 3  http://www.jfa.or.jp/match/matches/2012/0804ze...             5
# 4  http://www.jfa.or.jp/match/matches/2012/0804ze...             5
#
#    results_home  goal_away  goal_home  differ
# 0             0          1          0     1.0
# 1             0          2          0     0.0
# 2             0          3          0     0.0
# 3             1          1          0     1.0
# 4             1          2          0     0.0

# %%
#additional timeをプラス表記に
df_merged["time"] = df_merged["n_time"]
df_merged.loc[ (df_merged["a_time"] !=-1 ), "time"] = df_merged["n_time"].astype(str) + str("+") + df_merged["a_time"].astype(str)

df_merged=df_merged.loc[:,['id','leagu_name','year','month','day','round','team_home','team_away','url','results_away','results_home','goal_away','goal_home','time','player']]
df_merged
# Out:
#        id       leagu_name  year month  day             round  team_home  \
# 0       1  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.1 第1節    ＦＣ．ＳＥＴＡ
# 1       1  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.1 第1節    ＦＣ．ＳＥＴＡ
# 2       1  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.1 第1節    ＦＣ．ＳＥＴＡ
# 3       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節       川上ＦＣ
# 4       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節       川上ＦＣ
# 5       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節       川上ＦＣ
# 6       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節       川上ＦＣ
# 7       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No.2 第1節       川上ＦＣ
# 8       2  第36回全日本少年サッカー大会  2012   07月  31日       第1節No
# 10               2             5          1          0     3         富田 仁志
# 11               2             5          1          1     6         児玉 拓朗
# 12               2             5          1          2     8         児玉 拓朗
# 13               2             5          2          2    31         富田 仁志
# 14               2             5          2          3    36         児玉 拓朗
# 15               2             5          2          4    37         二木 七翼
# 16               2             5          2          5    38         児玉 拓朗
# 17               0             3          0          1     8         手塚 周太
# 18               0             3          0          2     9         小林 龍太
# 19               0             3          0          3    14         手塚 周太
# 20               2             1          0          1     1         佐藤 晧亮
# 21               2             1          1          1     9        大和田 涼太
# 22               2             1          2          1    34          岡本 竜
# 23               0             4          0          1    20         井上 竜稀
# 24               0             4          0          2    24         倉貫 直人
# 25               0             4          0          3    27         井上 竜稀
# 26               0             4          0          4    33         吉岡 翔太
# 27               2             3          1          0     6         閑田 隼斗
# 28               2             3          1          1    14         石井 将稀
# 29               2             3          1          2    36         宮嶋 俊弥
# ...            ...           ...        ...        ...   ...           ...
# 1021             1             2          0          1     4          吉田　樹
# 1022             1             2          0          2    38         鈴木　優太
# 1023             1             2          1          2    40         柳澤　周作
# 1024             3             1          1          0    23         曽根　玲英
# 1025             3             1          2          0    25          中川　海
# 1026             3             1          3          0    33         三富　嵩大
# 1027             3             1          3          1  40+2        木田　寿輝斗
# 1028             4             4          0          1     1         梶谷　政仁
# 1029             4             4          1          1     3          吉田　樹
# 1030             4             4          2          1     4          吉田　樹
# 1031             4             4          3          1     8         吉田　篤志
# 1032             4             4          3          2    16         阿部　光将
# 1033             4             4          3          3  20+2          岡本　竜
# 1034             4             4          4          3    34         粟野　健翔
# 1035             4             4          4          4    34          岡本　竜
# 1036             0             4          0          1     3         中村　駿太
# 1037             0             4          0          2    19         朝倉　涼介
# 1038             0             4          0          3    34         中村　駿太
# 1039             0             4          0          4    39          落合　陸
# 1040             3             1          0          1     3   ホール百音　アレックス
# 1041             3             1          1          1     8         水野　智大
# 1042             3             1          2          1    23          住田　将
# 1043             3             1          3          1    37         杉浦　文哉
# 1044             2             5          0          1    10         岡本　宗馬
# 1045             2             5          1          1    15        吉田　雄汰朗
# 1046             2             5          2          1    23          住田　将
# 1047             2             5          2          2    32         中村　駿太
# 1048             2             5          2          3    43         朝倉　涼介
# 1049             2             5          2          4    47         中村　駿太
# 1050             2             5          2          5    49         中村　駿太
#
# [1051 rows x 15 columns]

# %%
# 出力CSVの名前
from pathlib import Path
# newname = Path(in_file).stem
newname="u12_2012_2011"
print (newname)
# Out:
# u12_2012_2011

# %%
# タイムスタンプ
import os
from datetime import datetime
t = os.path.getmtime(in_file)
# エポック秒をdatetimeに変換
dt = datetime.fromtimestamp(t)
# datadate = dt.strftime('%Y%m%d%H%M')
datadate = dt.strftime('%m%d%H%M')
print (datadate)
# Out:
# 11040034

# %%
# 出力
df_merged.to_csv("./adj_" + newname + "_" + datadate + ".csv", 
          index=False   # 行インデックスを削除
         )

# %%
import subprocess
subprocess.run(['jupyter', 'nbconvert', '--to', 'python', 'dataformat_old.ipynb'])
# Out:
# CompletedProcess(args=['jupyter', 'nbconvert', '--to', 'python', 'dataformat_old.ipynb'], returncode=0)
